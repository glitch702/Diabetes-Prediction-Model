# %% [markdown]
# # CS 4038D Data Mining - Assignment

# %% [markdown]
# Dataset - Pima Indians Diabetes Database (https://www.kaggle.com/datasets )

# %% [markdown]
# DESCRIPTION - The objective of the dataset is to diagnostically predict whether or not a patient has diabetes, based on certain diagnostic measurements included in the dataset. In particular, all patients here are females, at least 21 years old of *Pima Indian heritage*.
# The datasets consist of several medical predictor (independent) variables and one target (dependent) variable, Outcome.

# %% [markdown]
# PROBLEM STATEMENT -  To accurately predict whether or not the patients in the dataset have diabetes

# %% [markdown]
# No. of samples in dataset - 768

# %% [markdown]
# No. of classes - 2 [0,1]

# %% [markdown]
# COLUMNS -
#
# 1) Pregnancies - Number of times pregnant
#
# 2) Glucose - Plasma glucose concentration
#
# 3) BloodPressure - Diastolic blood pressure (mm Hg)
#
# 4) SkinThickness - Triceps skin fold thickness (mm)
#
# 5) Insulin - 2-Hour serum insulin (mu U/ml)
#
# 6) BMI - Body mass index
#
# 7) DiabetesPedigreeFunction - Diabetes pedigree function
#
# 8) Age - Age (years)
#
# 9) Outcome - Class variable (0 or 1) - (Target variable) 268 of 768 are 1 (diabetic) , the others are 0 (not diabetic)

# %% [markdown]
# #### IMPORTING MODULES AND DATASET

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
db = pd.read_csv('diabetes.csv',sep=',')

# %%
db.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
db.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# Data contains '0' values. A value of zero does not make sense for these attributes and thus indicates missing value. Hence it needs to be cleaned. The '0' values are replaced with the mean value of the column.

# %% [markdown]
# ### DATA CLEANING

# %% [markdown]
# DATA CLEANING IN OPENREFINE -

# %% [markdown]
# #### Firstly we import the data set and create a project

# %%
from IPython.display import Image
Image(filename='0_openrefine.png')

# %% [markdown]
# ------

# %% [markdown]
# #### Now we convert all values into numeric values

# %%
Image(filename='1_Convert_to_numeric.png')

# %% [markdown]
# ----

# %% [markdown]
# #### Finally we replace the '0' values in the columns with the mean of the column

# %%
Image(filename='2_Removing_null.png')

# %%
#Importing dataset after cleaning using OpenRefine 
db = pd.read_csv('diabetes2.csv',sep=',')

# %%
db.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness     Insulin   BMI  \
# 0     6.000000    148.0           72.0      35.000000   79.799479  33.6
# 1     1.000000     85.0           66.0      29.000000   79.799479  26.6
# 2     8.000000    183.0           64.0      20.536458   79.799479  23.3
# 3     1.000000     89.0           66.0      23.000000   94.000000  28.1
# 4     3.845052    137.0           40.0      35.000000  168.000000  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
db.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    float64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(7), int64(2)
# memory usage: 54.1 KB

# %%
db.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      4.400782  121.681605      72.254807      26.606479  118.660163
# std       2.984162   30.436016      12.115932       9.631241   93.080358
# min       1.000000   44.000000      24.000000       7.000000   14.000000
# 25%       2.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.845052  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# Cleaning of data complete.

# %% [markdown]
# ### CORRELATION ANALYSIS

# %% [markdown]
# Generating a heatmap showing the correlation of the different columns

# %%
plt.figure(figsize=(12,10))  
p=sns.heatmap(db.corr(), annot=True,cmap ='RdYlGn')

# %% [markdown]
# #### INFERENCE - Here we see that all the variables have significant correlation to the 'outcome' and hence we do not need to drop any column before prediction

# %% [markdown]
# ### SPLITTING DATASET INTO TESTING AND TRAINING DATA

# %%
#Import functions for Model, Dataset Splitting and Evaluation
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import metrics
from sklearn import linear_model

# %%
X=db[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']].values
y=db['Outcome']

# %% [markdown]
# #### Creating the training and test sets using 0.2 as test size (i.e 80% of data for training rest 20% for model testing)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## QUESTION 1 - Running the different models on the dataset

# %% [markdown]
# ## DECISION TREE ALGORITHM

# %%
#creating classifier object for decision tree
clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)

# %%
#predicting
y_pred = clf.predict(X_test)

# %%
print("Accuracy on Test Set:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy on Test Set: 0.7662337662337663

# %%
# The confusion Matrix of the Model
cnf_matrix = metrics.confusion_matrix(y_test, y_pred)
cnf_matrix
# Out:
# array([[84, 23],
#        [13, 34]], dtype=int64)

# %%
# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %% [markdown]
# #### Displaying a comprehensive Report of the Decision Tree Model On overall Dataset

# %%
print(metrics.classification_report(y_test, clf.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.79      0.82       107
#            1       0.60      0.72      0.65        47
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.75      0.74       154
# weighted avg       0.78      0.77      0.77       154

# %% [markdown]
# ## NAIVE-BAYES CLASSIFIER MODEL

# %%
from sklearn.naive_bayes import GaussianNB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
#creating classifier object 
nb = GaussianNB()
nb.fit(X_train, y_train)

#predicting
nb_pred = nb.predict(X_test)

# %%
print("Accuracy on Test Set:",metrics.accuracy_score(y_test, nb_pred))
# Out:
# Accuracy on Test Set: 0.7727272727272727

# %%
# The confusion Matrix of the Model
cnf_matrix = metrics.confusion_matrix(y_test, nb_pred)
cnf_matrix
# Out:
# array([[92, 15],
#        [20, 27]], dtype=int64)

# %%
# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %% [markdown]
# #### Displaying a comprehensive Report of the Naive Bayes Model On overall Dataset

# %%
print(metrics.classification_report(y_test, nb.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.86      0.84       107
#            1       0.64      0.57      0.61        47
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.72      0.72       154
# weighted avg       0.77      0.77      0.77       154

# %% [markdown]
# ## KNN MODEL

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
neighbors=np.arange(1,9)
train_accuracy=np.empty(len(neighbors))
test_accuracy=np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    knn=KNeighborsClassifier(n_neighbors=k)
    
    knn.fit(X_train, y_train)
    
    train_accuracy[i]=knn.score(X_train, y_train)
    
    test_accuracy[i]=knn.score(X_test, y_test)

# %%
plt.figure(figsize=(10,10))
plt.title("K-NN varying number of neighbour")
plt.plot(neighbors, test_accuracy, label="Testing Accuracy")
plt.plot(neighbors, train_accuracy, label="Train Accuracy")
plt.legend()
plt.xlabel("Number of Neighbour")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# As test accuracy is highest at k=4, We adopt the KNeighborsClassifier with number of neighbours as 4

# %%
knn=KNeighborsClassifier(n_neighbors=4)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='uniform')

# %%
K_pred=knn.predict(X_test)
print("Accuracy on Test Set:",metrics.accuracy_score(y_test, K_pred))
# Out:
# Accuracy on Test Set: 0.7662337662337663

# %%
cnf_matrix = metrics.confusion_matrix(y_test, K_pred)
cnf_matrix
# Out:
# array([[94, 13],
#        [23, 24]], dtype=int64)

# %%
# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print(metrics.classification_report(y_test, knn.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.88      0.84       107
#            1       0.65      0.51      0.57        47
#
#     accuracy                           0.77       154
#    macro avg       0.73      0.69      0.71       154
# weighted avg       0.76      0.77      0.76       154

# %% [markdown]
# ## ANN MODEL

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# defining the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compiling the keras model

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X_train, y_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 78.65

# %%
# make class predictions with the model
predictions = model.predict_classes(X)
# summarize the first 5 cases
for i in range(10):
	print('%s => %d (expected %d)' % (X[i].tolist(), predictions[i], y[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 79.799479, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 79.799479, 26.6, 0.35100000000000003, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 20.536458, 79.799479, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.16699999999999998, 21.0] => 0 (expected 0)
# [3.8450519999999995, 137.0, 40.0, 35.0, 168.0, 43.1, 2.2880000000000003, 33.0] => 1 (expected 1)
# [5.0, 116.0, 74.0, 20.536458, 79.799479, 25.6, 0.201, 30.0] => 0 (expected 0)
# [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0] => 0 (expected 1)
# [10.0, 115.0, 69.105469, 20.536458, 79.799479, 35.3, 0.134, 29.0] => 1 (expected 0)
# [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0] => 1 (expected 1)
# [8.0, 125.0, 96.0, 20.536458, 79.799479, 31.992578, 0.23199999999999998, 54.0] => 0 (expected 1)

# %%
history = model.fit(X_train, y_train,validation_data = (X_test,y_test), epochs=100, batch_size=64,verbose=0)

# %%
#model accuracy
plt.figure(figsize=(12,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ## QUESTION 2 - Plot loss function against epochs

# %%
#model loss
plt.figure(figsize=(12,10))
plt.plot(history.history['loss']) 
plt.plot(history.history['val_loss']) 
plt.title('Model loss') 
plt.ylabel('Loss') 
plt.xlabel('Epoch') 
plt.legend(['Train', 'Test'], loc='upper left') 
plt.show()

# %% [markdown]
# ## Comparing the performance of ANN with any three different activation functions.

# %% [markdown]
# ### RELU

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# defining the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
# compiling the keras model

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X_train, y_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 65.10

# %% [markdown]
# ### TANH

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# defining the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='tanh'))
model.add(Dense(1, activation='tanh'))

# %%
# compiling the keras model

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X_train, y_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 68.10

# %% [markdown]
# ### SIGMOID

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# defining the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compiling the keras model

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X_train, y_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 68.36

# %% [markdown]
# #### INFERANCE -

# %% [markdown]
# ACCURACY for ANN using RELU activation function is 65.10

# %% [markdown]
# ACCURACY for ANN using TANH activation function is 68.10

# %% [markdown]
# ACCURACY for ANN using SIGMOID activation function is 68.36

# %% [markdown]
# #### CONCLUSION - SIGMOID activation function gave most accuracy and RELU activation function gave least accuracy

# %% [markdown]
# ## QUESTION 3 - Comparing and plotting ANN MODEL accuracy for different numbers of hidden nodes, like 1, 2, 3, square root of number of features = 3 (rounded), and half of the number of features = 4.

# %% [markdown]
# ### No. of Hidden nodes = 1

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = Sequential()
model.add(Dense(1, input_dim=8, activation='relu')) #1 HIDDEN NODE
model.add(Dense(1, activation='relu'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X_train, y_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 65.10

# %% [markdown]
# ### No. of Hidden nodes = 2

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = Sequential()
model.add(Dense(2, input_dim=8, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X_train, y_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 63.54

# %% [markdown]
# ### No. of Hidden nodes = 3

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = Sequential()
model.add(Dense(3, input_dim=8, activation='relu'))
#model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X_train, y_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 64.84

# %% [markdown]
# ### No. of Hidden nodes = 4

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = Sequential()
model.add(Dense(4, input_dim=8, activation='relu'))
model.add(Dense(1, activation='relu'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X_train, y_train, epochs=150, batch_size=10,verbose=0)

# evaluating the keras model
_, accuracy = model.evaluate(X, y, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 63.28

# %% [markdown]
# ### Plotting the different accuracies for comparion

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))  
# x axis values
x = [1,2,3,4]
# corresponding y axis values
y = [65.10,63.54,64.84,63.28]
  
# plotting the points 
plt.plot(x, y)
  
# naming the x axis
plt.xlabel('No. of Hidden Nodes')
# naming the y axis
plt.ylabel('Accuracy')
  
# giving a title to my graph
plt.title('Accuracy VS No. of Hidden Nodes')
  
# function to show the plot
plt.show()

# %% [markdown]
# #### No significant inference

# %% [markdown]
# ## QUESTION 4 - APPLYING MODELS ON DIVIDED DATASETS D1, D2, D3

# %% [markdown]
# Data sets have been manually divided and will now be imported.

# %%
#importing divided datasets
db1 = pd.read_csv('D1.csv',sep=',')
db2 = pd.read_csv('D2.csv',sep=',')
db3 = pd.read_csv('D3.csv',sep=',')

# %%
db1.shape #D1
# Out:
# (192, 9)

# %%
db2.shape #D2
# Out:
# (384, 9)

# %%
db3.shape #D3
# Out:
# (576, 9)

# %%
db.shape #D
# Out:
# (768, 9)

# %% [markdown]
# ## Decision tree

# %% [markdown]
# ### Splitting into training and testing

# %%
X1=db1[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']].values
y1=db1['Outcome']
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=0)

X2=db2[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']].values
y2=db2['Outcome']
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=0)

X3=db3[['Pregnancies','Glucose','BloodPressure','SkinThickness','Insulin','BMI','DiabetesPedigreeFunction','Age']].values
y3=db3['Outcome']
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.2, random_state=0)

# %%
#creating classifier object for decision tree
clf1 = DecisionTreeClassifier()
clf1 = clf1.fit(X1_train,y1_train)

clf2 = DecisionTreeClassifier()
clf2 = clf2.fit(X2_train,y2_train)

clf3 = DecisionTreeClassifier()
clf3 = clf3.fit(X3_train,y3_train)

# %%
y1_pred = clf1.predict(X1_test)
y2_pred = clf2.predict(X2_test)
y3_pred = clf3.predict(X3_test)

# %%
# The confusion Matrix of the Model
cnf1_matrix = metrics.confusion_matrix(y1_test, y1_pred)
cnf1_matrix
# Out:
# array([[19, 10],
#        [ 4,  6]], dtype=int64)

# %%
cnf2_matrix = metrics.confusion_matrix(y2_test, y2_pred)
cnf2_matrix
# Out:
# array([[38, 19],
#        [ 7, 13]], dtype=int64)

# %%
cnf3_matrix = metrics.confusion_matrix(y3_test, y3_pred)
cnf3_matrix
# Out:
# array([[61, 15],
#        [17, 23]], dtype=int64)

# %%
# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf1_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf2_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf3_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("FOR D1 - \n")
print(metrics.classification_report(y1_test, y1_pred)) 
print("FOR D2 - \n")
print(metrics.classification_report(y2_test, y2_pred)) 
print("FOR D3 - \n")
print(metrics.classification_report(y3_test, y3_pred))
# Out:
# FOR D1 -
#
#               precision    recall  f1-score   support
#
#            0       0.83      0.66      0.73        29
#            1       0.38      0.60      0.46        10
#
#     accuracy                           0.64        39
#    macro avg       0.60      0.63      0.60        39
# weighted avg       0.71      0.64      0.66        39
#
# FOR D2 -
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.67      0.75        57
#            1       0.41      0.65      0.50        20
#
#     accuracy                           0.66        77
#    macro avg       0.63      0.66      0.62        77
# weighted avg       0.73      0.66      0.68        77
#
# FOR D3 -
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.80      0.79        76
#            1       0.61      0.57      0.59        40
#
#     accuracy                           0.72       116
#    macro avg       0.69      0.69      0.69       116
# weighted avg       0.72      0.72      0.72       116

# %%
print("Accuracy on Test Set1:",metrics.accuracy_score(y1_test, y1_pred))
print("Accuracy on Test Set2:",metrics.accuracy_score(y2_test, y2_pred))
print("Accuracy on Test Set3:",metrics.accuracy_score(y3_test, y3_pred))
print("Accuracy on Test Set for main data set: 0.7597402597402597")
# Out:
# Accuracy on Test Set1: 0.6410256410256411
# Accuracy on Test Set2: 0.6623376623376623
# Accuracy on Test Set3: 0.7241379310344828
# Accuracy on Test Set for main data set: 0.7597402597402597

# %% [markdown]
# INFERENCE - With increase in number of samples , the accurancy of the model seems to increase. Irregularities and exceptions in this observation could be because of the uneven distribution of classes in the target variable of the data sets after splitting

# %% [markdown]
# ## Naive bayes

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=0)
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=0)
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.2, random_state=0)

# %%
#creating classifier object 
nb1 = GaussianNB()
nb1.fit(X1_train, y1_train)

#predicting
nb1_pred = nb1.predict(X1_test)

#creating classifier object 
nb2 = GaussianNB()
nb2.fit(X2_train, y2_train)

#predicting
nb2_pred = nb2.predict(X2_test)

#creating classifier object 
nb3 = GaussianNB()
nb3.fit(X3_train, y3_train)

#predicting
nb3_pred = nb3.predict(X3_test)

# %%
# The confusion Matrix of the Model for D1
cnf1_matrix = metrics.confusion_matrix(y1_test, nb1_pred)
cnf1_matrix
# Out:
# array([[26,  3],
#        [ 5,  5]], dtype=int64)

# %%
# The confusion Matrix of the Model for D2
cnf2_matrix = metrics.confusion_matrix(y2_test, nb2_pred)
cnf2_matrix
# Out:
# array([[45, 12],
#        [13,  7]], dtype=int64)

# %%
# The confusion Matrix of the Model for D3
cnf3_matrix = metrics.confusion_matrix(y3_test, nb3_pred)
cnf3_matrix
# Out:
# array([[67,  9],
#        [18, 22]], dtype=int64)

# %%
# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf1_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf2_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')

# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf3_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print("FOR D1 - \n")
print(metrics.classification_report(y1_test, nb1.predict(X1_test))) 
print("\nFOR D2 - \n")
print(metrics.classification_report(y2_test, nb2.predict(X2_test))) 
print("\nFOR D3 - \n")
print(metrics.classification_report(y3_test, nb3.predict(X3_test)))
# Out:
# FOR D1 -
#
#               precision    recall  f1-score   support
#
#            0       0.84      0.90      0.87        29
#            1       0.62      0.50      0.56        10
#
#     accuracy                           0.79        39
#    macro avg       0.73      0.70      0.71        39
# weighted avg       0.78      0.79      0.79        39
#
#
# FOR D2 -
#
#               precision    recall  f1-score   support
#
#            0       0.78      0.79      0.78        57
#            1       0.37      0.35      0.36        20
#
#     accuracy                           0.68        77
#    macro avg       0.57      0.57      0.57        77
# weighted avg       0.67      0.68      0.67        77
#
#
# FOR D3 -
#
#               precision    recall  f1-score   support
#
#            0       0.79      0.88      0.83        76
#            1       0.71      0.55      0.62        40
#
#     accuracy                           0.77       116
#    macro avg       0.75      0.72      0.73       116
# weighted avg       0.76      0.77      0.76       116

# %%
print("Accuracy on Test Set1:",metrics.accuracy_score(y1_test, nb1_pred))
print("Accuracy on Test Set2:",metrics.accuracy_score(y2_test, nb2_pred))
print("Accuracy on Test Set3:",metrics.accuracy_score(y3_test, nb3_pred))
print("Accuracy on Test Set for main data set: 0.7727272727272727")
# Out:
# Accuracy on Test Set1: 0.7948717948717948
# Accuracy on Test Set2: 0.6753246753246753
# Accuracy on Test Set3: 0.7672413793103449
# Accuracy on Test Set for main data set: 0.7727272727272727

# %% [markdown]
# INFERANCE - For this model, all the accuracies are in the same range. Only dataset - D2 seems to be lesser than the range and this can be due to uneven distribution of classes in the target variable of the training dataset upon spliting the main dataset

# %% [markdown]
# ## KNN MODEL

# %% [markdown]
# #### Applying on D1 -

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=0)

# %%
neighbors=np.arange(1,9)
train_accuracy=np.empty(len(neighbors))
test_accuracy=np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    knn1=KNeighborsClassifier(n_neighbors=k)
    
    knn1.fit(X1_train, y1_train)
    
    train_accuracy[i]=knn1.score(X1_train, y1_train)
    
    test_accuracy[i]=knn1.score(X1_test, y1_test)

# %%
plt.figure(figsize=(10,10))
plt.title("K-NN varying number of neighbour")
plt.plot(neighbors, test_accuracy, label="Testing Accuracy")
plt.plot(neighbors, train_accuracy, label="Train Accuracy")
plt.legend()
plt.xlabel("Number of Neighbour")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# #### As test accracy is highest at k=4, We adopt the KNeighborsClassifier with number of neighbours as 4

# %%
knn1=KNeighborsClassifier(n_neighbors=4)
knn1.fit(X1_train, y1_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=4, p=2,
#                      weights='uniform')

# %%
K1_pred=knn.predict(X1_test)
print("Accuracy on Test Set:",metrics.accuracy_score(y1_test, K1_pred))
# Out:
# Accuracy on Test Set: 0.7435897435897436

# %%
cnf1_matrix = metrics.confusion_matrix(y1_test, K1_pred)
cnf1_matrix
# Out:
# array([[26,  3],
#        [ 7,  3]], dtype=int64)

# %%
# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf1_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print(metrics.classification_report(y1_test, knn1.predict(X1_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.79      0.93      0.86        29
#            1       0.60      0.30      0.40        10
#
#     accuracy                           0.77        39
#    macro avg       0.70      0.62      0.63        39
# weighted avg       0.74      0.77      0.74        39

# %% [markdown]
# #### Applying on D2

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=0)

# %%
neighbors=np.arange(1,9)
train_accuracy=np.empty(len(neighbors))
test_accuracy=np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    knn2=KNeighborsClassifier(n_neighbors=k)
    
    knn2.fit(X2_train, y2_train)
    
    train_accuracy[i]=knn2.score(X2_train, y2_train)
    
    test_accuracy[i]=knn2.score(X2_test, y2_test)

# %%
plt.figure(figsize=(10,10))
plt.title("K-NN varying number of neighbour")
plt.plot(neighbors, test_accuracy, label="Testing Accuracy")
plt.plot(neighbors, train_accuracy, label="Train Accuracy")
plt.legend()
plt.xlabel("Number of Neighbour")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# #### As test accracy is highest at k=8, We adopt the KNeighborsClassifier with number of neighbours as 8

# %%
knn2=KNeighborsClassifier(n_neighbors=8)
knn2.fit(X2_train, y2_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=8, p=2,
#                      weights='uniform')

# %%
K2_pred=knn2.predict(X2_test)
print("Accuracy on Test Set:",metrics.accuracy_score(y2_test, K2_pred))
# Out:
# Accuracy on Test Set: 0.6883116883116883

# %%
cnf2_matrix = metrics.confusion_matrix(y2_test, K2_pred)
cnf2_matrix
# Out:
# array([[47, 10],
#        [14,  6]], dtype=int64)

# %%
# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf2_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print(metrics.classification_report(y2_test, knn2.predict(X2_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.82      0.80        57
#            1       0.38      0.30      0.33        20
#
#     accuracy                           0.69        77
#    macro avg       0.57      0.56      0.56        77
# weighted avg       0.67      0.69      0.68        77

# %% [markdown]
# #### Applying on D3

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.2, random_state=0)

# %%
neighbors=np.arange(1,9)
train_accuracy=np.empty(len(neighbors))
test_accuracy=np.empty(len(neighbors))

for i,k in enumerate(neighbors):
    knn3=KNeighborsClassifier(n_neighbors=k)
    
    knn3.fit(X3_train, y3_train)
    
    train_accuracy[i]=knn3.score(X3_train, y3_train)
    
    test_accuracy[i]=knn3.score(X3_test, y3_test)

# %%
plt.figure(figsize=(10,10))
plt.title("K-NN varying number of neighbour")
plt.plot(neighbors, test_accuracy, label="Testing Accuracy")
plt.plot(neighbors, train_accuracy, label="Train Accuracy")
plt.legend()
plt.xlabel("Number of Neighbour")
plt.ylabel("Accuracy")
plt.show()

# %% [markdown]
# As test accracy is highest at k=5, We adopt the KNeighborsClassifier with number of neighbours as 5

# %%
knn3=KNeighborsClassifier(n_neighbors=5)
knn3.fit(X3_train, y3_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
K3_pred=knn3.predict(X3_test)
print("Accuracy on Test Set:",metrics.accuracy_score(y3_test, K3_pred))
# Out:
# Accuracy on Test Set: 0.7758620689655172

# %%
cnf3_matrix = metrics.confusion_matrix(y3_test, K3_pred)
cnf3_matrix
# Out:
# array([[65, 11],
#        [15, 25]], dtype=int64)

# %%
# Plot the Confusion Matrix as a HeatMap
class_names=[0,1] # Name  of classes
fig, ax = plt.subplots()
tick_marks = np.arange(len(class_names))
plt.xticks(tick_marks, class_names)
plt.yticks(tick_marks, class_names)
# create heatmap
sns.heatmap(pd.DataFrame(cnf3_matrix), annot=True, cmap="YlGnBu" ,fmt='g')
ax.xaxis.set_label_position("top")
plt.tight_layout()
plt.title('Confusion matrix', y=1.1)
plt.ylabel('Actual label')
plt.xlabel('Predicted label')
# Out:
# Text(0.5, 257.44, 'Predicted label')

# %%
print(metrics.classification_report(y3_test, knn3.predict(X3_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.86      0.83        76
#            1       0.69      0.62      0.66        40
#
#     accuracy                           0.78       116
#    macro avg       0.75      0.74      0.75       116
# weighted avg       0.77      0.78      0.77       116

# %% [markdown]
# INFERENCE -

# %% [markdown]
# ACCURACY on test set for D1 is 0.7435897435897436

# %% [markdown]
# ACCURACY on test set for D2 is 0.6883116883116883

# %% [markdown]
# ACCURACY on test set for D3 is 0.7758620689655172

# %% [markdown]
# ACCURACY on test set for D (Main set) is 0.7662337662337663

# %% [markdown]
# INFERANCE - For this model, all the accuracies are in the same range. Only dataset - D2 seems to be lesser than the range and this can be due to uneven distribution of classes in the target variable of the training dataset upon spliting the main dataset

# %% [markdown]
# ### ANN MODEL

# %% [markdown]
# #### Applying on D1

# %%
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=0.2, random_state=0)

# %%
# defining the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compiling the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X1_train, y1_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X1, y1, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 77.60

# %%
# make class predictions with the model
predictions = model.predict_classes(X1)
# summarize the first 5 cases
for i in range(10):
	print('%s => %d (expected %d)' % (X1[i].tolist(), predictions[i], y1[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 79.799479, 33.6, 0.627, 50.0] => 0 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 79.799479, 26.6, 0.35100000000000003, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 20.536458, 79.799479, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.16699999999999998, 21.0] => 0 (expected 0)
# [3.8450519999999995, 137.0, 40.0, 35.0, 168.0, 43.1, 2.2880000000000003, 33.0] => 1 (expected 1)
# [5.0, 116.0, 74.0, 20.536458, 79.799479, 25.6, 0.201, 30.0] => 0 (expected 0)
# [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0] => 0 (expected 1)
# [10.0, 115.0, 69.105469, 20.536458, 79.799479, 35.3, 0.134, 29.0] => 1 (expected 0)
# [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0] => 1 (expected 1)
# [8.0, 125.0, 96.0, 20.536458, 79.799479, 31.992578, 0.23199999999999998, 54.0] => 0 (expected 1)

# %%
history = model.fit(X1_train, y1_train,validation_data = (X1_test,y1_test), epochs=150, batch_size=10,verbose=0)

# %%
#model accuracy
plt.figure(figsize=(12,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Applying on D2

# %%
X2_train, X2_test, y2_train, y2_test = train_test_split(X2, y2, test_size=0.2, random_state=0)

# %%
# defining the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compiling the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X2_train, y2_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X2, y2, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 78.12

# %%
# make class predictions with the model
predictions = model.predict_classes(X2)
# summarize the first 5 cases
for i in range(10):
	print('%s => %d (expected %d)' % (X2[i].tolist(), predictions[i], y2[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 79.799479, 33.6, 0.627, 50.0] => 0 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 79.799479, 26.6, 0.35100000000000003, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 20.536458, 79.799479, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.16699999999999998, 21.0] => 0 (expected 0)
# [3.8450519999999995, 137.0, 40.0, 35.0, 168.0, 43.1, 2.2880000000000003, 33.0] => 1 (expected 1)
# [5.0, 116.0, 74.0, 20.536458, 79.799479, 25.6, 0.201, 30.0] => 0 (expected 0)
# [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0] => 0 (expected 1)
# [10.0, 115.0, 69.105469, 20.536458, 79.799479, 35.3, 0.134, 29.0] => 1 (expected 0)
# [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0] => 1 (expected 1)
# [8.0, 125.0, 96.0, 20.536458, 79.799479, 31.992578, 0.23199999999999998, 54.0] => 0 (expected 1)

# %%
history = model.fit(X2_train, y2_train,validation_data = (X2_test,y2_test), epochs=150, batch_size=10,verbose=0)

# %%
#model accuracy
plt.figure(figsize=(12,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Applying on D3

# %%
X3_train, X3_test, y3_train, y3_test = train_test_split(X3, y3, test_size=0.2, random_state=0)

# %%
# defining the keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
# compiling the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# fit the keras model on the dataset
history = model.fit(X3_train, y3_train, epochs=150, batch_size=10,verbose=0)

# %%
# evaluating the keras model
_, accuracy = model.evaluate(X3, y3, verbose=0)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# Accuracy: 79.34

# %%
# make class predictions with the model
predictions = model.predict_classes(X3)
# summarize the first 5 cases
for i in range(10):
	print('%s => %d (expected %d)' % (X3[i].tolist(), predictions[i], y3[i]))
# Out:
# [6.0, 148.0, 72.0, 35.0, 79.799479, 33.6, 0.627, 50.0] => 1 (expected 1)
# [1.0, 85.0, 66.0, 29.0, 79.799479, 26.6, 0.35100000000000003, 31.0] => 0 (expected 0)
# [8.0, 183.0, 64.0, 20.536458, 79.799479, 23.3, 0.672, 32.0] => 1 (expected 1)
# [1.0, 89.0, 66.0, 23.0, 94.0, 28.1, 0.16699999999999998, 21.0] => 0 (expected 0)
# [3.8450519999999995, 137.0, 40.0, 35.0, 168.0, 43.1, 2.2880000000000003, 33.0] => 1 (expected 1)
# [5.0, 116.0, 74.0, 20.536458, 79.799479, 25.6, 0.201, 30.0] => 0 (expected 0)
# [3.0, 78.0, 50.0, 32.0, 88.0, 31.0, 0.248, 26.0] => 0 (expected 1)
# [10.0, 115.0, 69.105469, 20.536458, 79.799479, 35.3, 0.134, 29.0] => 0 (expected 0)
# [2.0, 197.0, 70.0, 45.0, 543.0, 30.5, 0.158, 53.0] => 1 (expected 1)
# [8.0, 125.0, 96.0, 20.536458, 79.799479, 31.992578, 0.23199999999999998, 54.0] => 0 (expected 1)

# %%
history = model.fit(X3_train, y3_train,validation_data = (X3_test,y3_test), epochs=150, batch_size=10,verbose=0)

# %%
#model accuracy
plt.figure(figsize=(12,10))
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# INFERENCE -

# %% [markdown]
# ACCURACY on test set for D1 is 0.7760

# %% [markdown]
# ACCURACY on test set for D2 is 0.7812

# %% [markdown]
# ACCURACY on test set for D3 is 0.7934

# %% [markdown]
# ACCURACY on test set for D (Main) is 0.7865

# %% [markdown]
# #### INFERENCE - For ANN model, all the accuracies seem to be in the same range.
